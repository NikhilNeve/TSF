# %% [markdown]
# <H1><center> THE SPARK FOUNDATION

# %% [markdown]
# ## Data Science and Business Analytics Internship
# #### Batch- GRIP APRIL'23
# ### TASK 3: Exploratory Data Analysis - Retail
# ### Author : Nikhil Neve
#
# #### Problem Statement
# >* Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# >* As a business manager, try to find out the weak areas where you can work to make more profit?
# >* What all business problems you can derive by exploring the data

# %% [markdown]
# #### Required Pacakges
# > Packages need installed in Jupiter Notebook or it can be install
# >>* !pip3 install pandas                        ----------    # Library for data manipulation and analysis
# >>* !pip3 install numpy                         ----------    # Library for numerical operation and array manipulation
# >>* !pip3 install matplotlib                    ----------    # Library for visualization
# >>* !pip3 install seaborn                       ----------    # Library for advanced visualization

# %% [markdown]
# #### Importing required libraries

# %%
import pandas as pd
import numpy as np                                         
import matplotlib.pyplot as plt 
import seaborn as sns   
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading data from local system
data=pd.read_csv("E:\Internship\The Spark Foundation\Task 3\SampleSuperstore.csv")
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# #### Here is the remote link to get SampleSuperstore dataset:- https://bit.ly/3i4rbWl

# %%
#rows and columns in DataFrame data
data.shape
# Out:
# (9994, 13)

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
#Check wheather data has null value
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Data type of data 
data.dtypes
# Out:
# Ship Mode         object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code       object
# Region            object
# Category          object
# Sub-Category      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# Profit Margin    float64
# dtype: object

# %%
#Check for duplicacy in dataset.
data.duplicated().sum()
# Out:
# 17

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (9977, 13)

# %%
#Postal code should be represent as string
data['Postal Code'] = data['Postal Code'].astype(str)

# %%
#Summary of Descriptive Statistics 
data.describe()
# Out:
#               Sales     Quantity     Discount      Profit  Profit Margin
# count   9977.000000  9977.000000  9977.000000  9977.00000    9977.000000
# mean     230.148902     3.790719     0.156278    28.69013      12.011354
# std      623.721409     2.226657     0.206455   234.45784      46.663769
# min        0.444000     1.000000     0.000000 -6599.97800    -275.000000
# 25%       17.300000     2.000000     0.000000     1.72620       7.500000
# 50%       54.816000     3.000000     0.200000     8.67100      27.000000
# 75%      209.970000     5.000000     0.200000    29.37200      36.250000
# max    22638.480000    14.000000     0.800000  8399.97600      50.000000

# %%
data.nunique()
# Out:
# Ship Mode           4
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Category            3
# Sub-Category       17
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# Profit Margin     525
# dtype: int64

# %%
data.State.unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
#Count the number of occurrences of each unique value in the 'Segment' and bar plot of different Segments.
c= data.Segment.value_counts()
print(c)

plt.figure(figsize=(8, 6))
plt.bar(c.index, c.values, color=['blue', 'green', 'red'])
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64
# <BarContainer object of 3 artists>

# %% [markdown]
# #### Insights-
# >* It appears that the data has a higher proportion of customers in the "Consumer" segment compared to the other segments with 5183 occurrences in the data.

# %%
#Count the number of occurrences of each unique value in the 'Ship Mode' and distribution of different shipping modes
c=data['Ship Mode'].value_counts()
print(c)
plt.figure(figsize=(8, 8))
d= data['Ship Mode'].value_counts().plot.pie(colors=['blue','red','pink', 'yellow'],autopct='%.2f%%')
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %% [markdown]
# #### Insights-
# >* Most commonly used shipping mode is Standard Class, followed by Second Class, First Class, and Same Day in descending order.

# %%
#Count the number of occurance of each unique value in Region. and display distribution of regional data.
c=data['Region'].value_counts()
print(c)
plt.figure(figsize=(8, 8))
d= data['Region'].value_counts().plot.pie(colors=['orange','yellow','blue','red'],autopct='%.2f%%')
d
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64
# <AxesSubplot:ylabel='Region'>

# %% [markdown]
# #### Insights-
# >* West region has the highest count, followed by the East, Central, and South regions in decreasing order.

# %%
#Count the number of ocuurance of unique value in Category and the distribution of product categories  using pie chart.
c=data['Category'].value_counts()
print(c) 
# Plot a pie chart of the 'Category' column
plt.figure(figsize=(8, 8))
data['Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')



#using seaborn
#sns.countplot(x='Category', data=data)
#plt.show()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# #### Insights-
# >* Majority of the products fall under the Office Supplies category, followed by Furniture and Technology categories in descending order.

# %%
# Count the unique value occurance in Sub-Category using bar chart.

subcat_count = data['Sub-Category'].value_counts()
print(subcat_count)
# Plot a bar chart of the sub-category counts
plt.figure(figsize=(14,8))
subcat_count.plot.bar()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# #### Insight-
# >* Most common sub-category of product is Binders, followed by Paper, Furnishings, Phones, and Storage in descending order.

# %%
#Count the number of unique value occurance in 'Quantity'..Quantity of Products Sold by Sub-Category using seaborn library
data.Quantity.value_counts()
subcat_quantity = data.groupby('Sub-Category')['Quantity'].sum().sort_values(ascending=False)
print(subcat_quantity)



# Group quantity by sub-category
subcat_quantity = data.groupby('Sub-Category')['Quantity'].sum().sort_values(ascending=False)

# Create a bar plot using Seaborn
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x='Quantity', y='Sub-Category', data=subcat_quantity.reset_index(), ax=ax)
ax.set_title('Quantity of Products Sold by Sub-Category')
ax.set_xlabel('Quantity')
ax.set_ylabel('Sub-Category')
plt.show()
# Out:
# Sub-Category
# Binders        5971
# Paper          5144
# Furnishings    3560
# Phones         3289
# Storage        3158
# Art            2996
# Accessories    2976
# Chairs         2351
# Appliances     1729
# Labels         1396
# Tables         1241
# Fasteners       914
# Envelopes       906
# Bookcases       868
# Supplies        647
# Machines        440
# Copiers         234
# Name: Quantity, dtype: int64

# %% [markdown]
# #### Insights-
# >* The sub-category with the highest quantity of products sold is 'Binders', followed by 'Paper' and 'Furnishings'.
# >* 'Copiers', 'Machines', and 'Supplies' have the lowest quantity of products sold.
# >* The majority of sub-categories have sold around 1,000-3,000 products.

# %%
#Average sales and average profit by category and region.
plt.figure(figsize=(12,6))

#First Plot
plt.subplot(1, 2, 1)
df_subset = data[['Category', 'Region', 'Sales']]
df_subset = df_subset.groupby(['Category', 'Region']).mean().reset_index()
sns.barplot(x='Category', y='Sales', hue='Region', data=df_subset)
plt.title('Average Sales by Category and Region')

# Second Plot
plt.subplot(1,2,2)
df_subset = data[['Category', 'Region', 'Profit']]
df_subset = df_subset.groupby(['Category', 'Region']).mean().reset_index()
sns.barplot(x='Category', y='Profit', hue='Region', data=df_subset)
plt.title('Average Profit by Category and Region')

# Adjust the layout and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Insights-
# >Ist plot
# >>* The first plot indicates that the highest average sales come from the Technology category, followed by Furniture and Office Supplies.
# >>* The East region has the highest average sales overall, followed by the West and Central regions.
#
# >IInd Plot
# >>* The second plot indicates that the highest average profit comes from the Technology category, followed by Office Supplies and Furniture.
# >>* The West region has the highest average profit overall, followed by the East and Central regions.

# %%
# Group the data by category and sub-category and get the count
csc = data.groupby(['Category', 'Sub-Category']).size()
print(csc)

# Reshape the data into a pivot table
csc = csc.unstack(level=0)


# Plot the stacked bar chart
colors = ['blue', 'green', 'red']
csc.plot(kind='bar', stacked=True, figsize=(20, 10), color=colors)
plt.title('Sub-Category Count by Category')
plt.xlabel('Sub-Category')
plt.ylabel('Count')
plt.legend(title='Category', loc='upper left')
plt.show()
# Out:
# Category         Sub-Category
# Furniture        Bookcases        228
#                  Chairs           615
#                  Furnishings      956
#                  Tables           319
# Office Supplies  Appliances       466
#                  Art              795
#                  Binders         1522
#                  Envelopes        254
#                  Fasteners        217
#                  Labels           363
#                  Paper           1359
#                  Storage          846
#                  Supplies         190
# Technology       Accessories      775
#                  Copiers           68
#                  Machines         115
#                  Phones           889
# dtype: int64

# %% [markdown]
# #### Insights-
# >* The "Office Supplies" category has the most sub-categories with 9, followed by "Furniture" with 4 and "Technology" with 4.
# >* The sub-category with the most items is "Binders" with 1522, followed by "Paper" with 1359 and "Storage" with 846.
# >* The "Furniture" category has a relatively low number of items in comparison to the other two categories.
# >* The "Technology" category has the least number of sub-categories but the items in these sub-categories have relatively high counts.

# %%
corr = data.corr()
print(corr)

# Plot the correlation matrix using a heatmap
sns.heatmap(corr, annot=True, cmap='BrBG')
plt.show()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# #### Insights
# >* Sales and Profit are moderately positively correlated (0.48), indicating that increasing Sales can lead to increased Profit.
# >* Sales is the most important factor affecting Profit, while Quantity and Discount have a smaller influence on Profit.
# >* Quantity and Profit have a weak positive correlation (0.07), suggesting that there is a small tendency for Profit to increase as Quantity increases.
# >* Discount and Profit have a weak negative correlation (-0.22), meaning that increasing Discount can cause a slight decrease in Profit.

# %%
# Group the data by Category and calculate total sales and profit
category_sales_profit = data.groupby('Category')[['Sales', 'Profit']].sum()

# Create a bar plot to show the total sales and profit for each category
fig, ax = plt.subplots(figsize=(10, 6))
category_sales_profit.plot(kind='bar', ax=ax)
ax.set_title('Total Sales and Profit by Category')
ax.set_xlabel('Category')
ax.set_ylabel('Amount')

plt.show()

# %% [markdown]
# #### Insights-
# >* Technology has Highest Sales and Profit
# >* Priofit margin for all seems moderate but in case of furniture category its very less.
# >* Indicates Comapany may need to re-price or improving products and try to understand customer needs in deep related to this Category.

# %%
# Calculate total sales and profit by customer segment
segment_sales_profit = data.groupby('Segment')[['Sales', 'Profit']].sum()
print(segment_sales_profit)
# Create an area plot using stackplot
fig, ax = plt.subplots(figsize=(10, 6))
ax.stackplot(segment_sales_profit.index, segment_sales_profit['Sales'], segment_sales_profit['Profit'], labels=['Sales', 'Profit'])
ax.legend(loc='upper left')
ax.set_title('Customer Segment Sales and Profit')
ax.set_xlabel('Customer Segment')
ax.set_ylabel('Amount')
plt.show()
# Out:
#                     Sales       Profit
# Segment
# Consumer     1.160833e+06  134007.4413
# Corporate    7.060701e+05   91954.9798
# Home Office  4.292927e+05   60279.0015

# %% [markdown]
# #### Insights-
# >*  Consumer segment has the highest sales and profit, followed by the Corporate segment, and the Home Office segment has the lowest sales and profit.
# >* It means we can target the Home Office segment for improvement and coming up with strategies to increase sales and profit for that segment.

# %%
# Group the data by state and calculate the total sales
state_sales = data.groupby('State')['Sales'].sum().reset_index()
#print(state_sales)

# Sort the data by sales in descending order
state_sales = state_sales.sort_values(by='Sales', ascending=False)

# Create a bar chart to visualize the sales by state
plt.figure(figsize=(14,8))
plt.bar(x=state_sales['State'], height=state_sales['Sales'])
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Total Sales by State')
plt.show()

# %% [markdown]
# #### Insights-
# >* California has the highest total sales, followed by New York and Texas.
# >* The lowest sales are in North Dakota, West Virginia, and Maine.
# >* The analysis of sales figures by state can help businesses optimize their sales strategies to increase revenue and profitability.

# %%
# Calculate total profit by state
state_profit = data.groupby('State')['Profit'].sum().sort_values(ascending=False)
# print(state_profit)
# Create a bar plot
fig, ax = plt.subplots(figsize=(15,8))
sns.barplot(x=state_profit.index, y=state_profit.values)
ax.set_title('Total Profit by State')
ax.set_xlabel('State')
ax.set_ylabel('Profit')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights-
# >* California, New York, and Washington are the top three states with the highest profit. On the other hand, Texas, Ohio, and Pennsylvania are the three states with the lowest profit.

# %%
# Calculate profit margin with sub-category
data['Profit Margin'] = (data['Profit']/data['Sales'])*100
subcat_profit_margin = data.groupby('Sub-Category')['Profit Margin'].mean().sort_values(ascending=False).to_frame().reset_index()
print(subcat_profit_margin)
# Create a horizontal bar plot using Seaborn
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(x='Profit Margin', y='Sub-Category', data=subcat_profit_margin, ax=ax)
ax.set_title('Profit Margin by Sub-Category')
ax.set_xlabel('Profit Margin (%)')
ax.set_ylabel('Sub-Category')
plt.show()
# Out:
#    Sub-Category  Profit Margin
# 0        Labels      42.952479
# 1         Paper      42.558131
# 2     Envelopes      42.313976
# 3       Copiers      31.719363
# 4     Fasteners      29.917051
# 5           Art      25.162264
# 6   Accessories      21.820968
# 7   Furnishings      13.690638
# 8        Phones      11.922197
# 9      Supplies      11.203947
# 10      Storage       8.911348
# 11       Chairs       4.396574
# 12     Machines      -7.202622
# 13    Bookcases     -12.664007
# 14       Tables     -14.772653
# 15   Appliances     -15.686934
# 16      Binders     -19.857643

# %% [markdown]
# #### Insight
# >* The sub-categories with the highest profit margin are Labels, Paper, and Envelopes, followed by Copiers and Fasteners.
# >* The sub-categories with negative profit margin are Binders, Appliances, Tables, Bookcases, and Machines.

# %% [markdown]
# # <hi><center>Conclusion

# %% [markdown]
# As a Business Manager (Hypothesis Case) here's my finding with conclusion
# * The sales and profits are positively correlated, indicating that increasing sales can lead to higher profits.
#
#
# * The sales and profits are higher in the Western and Eastern regions of the country, while the Central region has the lowest sales and profits.
#
#
# * This finding can prompt businesses to analyze the reasons behind this trend and make necessary adjustments.
#
#
# * The majority of the orders are for the Standard shipment mode, followed by Second Class and First Class. However, the highest profits come from orders with the Same Day shipment mode. This finding can prompt businesses to focus on providing faster shipment options to their customers to increase profitability.
#
#
# * The sub-categories with the highest profit margin are Labels, Paper, and Envelopes, followed by Copiers and Fasteners. On the other hand, the sub-categories with negative profit margins are Binders, Appliances, Tables, Bookcases, and Machines. This finding can prompt businesses to analyze their pricing strategy and make necessary adjustments for the sub-categories with low profit margins.
#
#
# * There is a negative correlation between discount and profit, indicating that higher discounts lead to lower profits. This finding can prompt businesses to rethink their discount strategy and optimize it for maximum profitability.

# %% [markdown]
# ### <h1><center>  Thank You!
#
#     Please visit my GitHub profile to see the code for this project.
#     Here's the link: "https://github.com/NikhilNeve/TSF"
